# %%
import pandas
import numpy
from sklearn import datasets
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.cross_validation import KFold
from sklearn.grid_search import GridSearchCV


#Загрузите объекты из новостного датасета 20 newsgroups, относящиеся к категориям "космос" и "атеизм".
newsgroups = datasets.fetch_20newsgroups(
                    subset='all', 
                    categories=['alt.atheism', 'sci.space']
             )
X = newsgroups.data
target = newsgroups.target

#Вычислите TF-IDF-признаки для всех текстов.
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X).toarray()
words = vectorizer.get_feature_names()

#Подберите минимальный лучший параметр С из множества [0.00001 ... 1000000] для SVM с линейным ядром при помощи крос-валидации по 5 блокам.
#Укажите random_state = 241 и для KFold, и для SVM.
#В качестве меры качества используйте долю верных ответов.
grid = {'C': numpy.power(10.0, numpy.arange(-5,6))}
cv = KFold(target.size, n_folds=5, shuffle=True, random_state=241)
clf = SVC(kernel = 'linear', random_state = 241)
gs = GridSearchCV(clf, grid, scoring = 'accuracy', cv = cv)
gs.fit(X_train, target)

#score = 0
#C = 0
#for a in gs.grid_scores_:
   # if a.mean_validation_score > score:
   #     score = a.mean_validation_score
   #     C = a.parameters['C']

#У GridSearchCV есть поле best_estimator_
bC = gs.best_estimator_.C

#Обучите SVM по всей выборке с оптимальным параметром C, найденным на предыдущем шаге.
model = SVC(kernel = 'linear', random_state = 241, C = bC)
model = model.fit(X_train, target)

#Найдите 10 слов с наибольшим по модулю весом. Они являются ответом на это задание.
#Укажите их через запятую или пробел, в нижнем регистре, в лексикографическом порядке.
weights = []
for i in model.coef_.T: #транспонируем, тк иначе коэфы идут строкой
    weights.append(abs(i[0]))

dictionary = dict(zip(words, weights))
best = pandas.DataFrame(dictionary, index = [0]).transpose() #без транспонирования все идет строкой
best.columns = ['weights']
best.sort_values(['weights'], ascending=[False],inplace=True)
best
# Out:
#                        weights
# space                 2.663165
# god                   1.920379
# atheism               1.254690
# atheists              1.249180
# moon                  1.201611
# sky                   1.180132
# religion              1.139081
# bible                 1.130612
# keith                 1.097094
# sci                   1.029307
# cobb                  1.027661
# nasa                  1.024223
# religious             1.001445
# mathew                0.991887
# edu                   0.949986
# halat                 0.926508
# islamic               0.925736
# unm                   0.897104
# is                    0.879993
# dc                    0.870679
# jesus                 0.847756
# sgi                   0.844286
# launch                0.838716
# wrote                 0.832950
# christian             0.825875
# pope                  0.824022
# gamma                 0.823525
# ca                    0.818438
# re                    0.813480
# he                    0.812145
# ...                        ...
# mildly                0.000000
# aerodynamically       0.000000
# mileage               0.000000
# aerodynamical         0.000000
# microscum             0.000000
# microsatellites       0.000000
# micrometeroid         0.000000
# micrometeoroid        0.000000
# affiars               0.000000
# mg7                   0.000000
# mgds                  0.000000
# mgl                   0.000000
# mgz                   0.000000
# mhd                   0.000000
# mhepy4g7ge8mo5wpsivx  0.000000
# mholderm              0.000000
# mhz                   0.000000
# affectionate          0.000000
# mica                  0.000000
# michele               0.000000
# afal                  0.000000
# michoud               0.000000
# microelectronics      0.000000
# microfiche            0.000000
# microfilm             0.000000
# microgravity          0.000000
# microlight            0.000000
# micrometeor           0.000000
# micrometeorites       0.000000
# nauseam               0.000000
#
# [28382 rows x 1 columns]
